# %% [markdown]
# # 👋 欢迎来到你的本地 Jupyter Notebook
#
# 这是我在你电脑上创建的第一个笔记本文件 (`.ipynb`)。
# 在这里，你可以像在 Colab 里一样运行代码、查看表格和图表。
#
# ## 1. 试着运行下面这个代码块 (Shift + Enter)

# %%
print("Hello, Local Python Environment!")

# 简单的数学计算
a = 100
b = 200
print(f"{a} + {b} = {a+b}")

# %% [markdown]
# ## 2. 看看 Pandas 表格长什么样
# 不需要 print，直接把变量名放在最后一行，它就会漂亮地展示出来。

# %%
import pandas as pd

data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'City': ['Beijing', 'Shanghai', 'Shenzhen']
}

df = pd.DataFrame(data)
df  # <--- 直接这样写，效果最好！

# %% [markdown]
# ## 3. 试试画图功能
# 如果你安装了 Jupyter 插件，图表会直接显示在这里 👇

# %%
import matplotlib.pyplot as plt

# 简单的折线图
x = [1, 2, 3, 4, 5]
y = [10, 15, 13, 18, 20]

plt.plot(x, y)
plt.title("My First Plot")
plt.show()
